# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# create a PyTorch tensor
x = torch.linspace(-10, 10, 100)

# %%
# Creating another Tensor with an array
input = torch.Tensor([1, -2, 3, -4, 5, -6])

# %% [markdown]
# # Linear Activation Function

# %%
# Linear activation doesn't alter the input, acting as an identity function
def linear_activation(x):
    return x

# %%
# Passing the array to linear activation function
output = linear_activation(input)

print(output)
# Out:
# tensor([ 1., -2.,  3., -4.,  5., -6.])

# %%
# apply the linear activation function to the tensor
y = linear_activation(x)

# plot the results with a custom color
plt.plot(x.numpy(), y.numpy(), color='red')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Linear Activation Function')
plt.show()

# %% [markdown]
# # Sigmoid Activation Function

# %%
# Calling the sigmoid function
sig = nn.Sigmoid()

# Applying sigmoid to the tensor
output = sig(input)

print(output)
# Out:
# tensor([0.7311, 0.1192, 0.9526, 0.0180, 0.9933, 0.0025])

# %%
# apply the sigmoid activation function to the tensor
y = torch.sigmoid(x)

# plot the results with a custom color
plt.plot(x.numpy(), y.numpy(), color='purple')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Sigmoid Activation Function')
plt.show()

# %% [markdown]
# # Tanh Activation Function

# %%
# Calling the Tanh function
t = nn.Tanh()

# Applying Tanh to the tensor
output = t(input)
print(output)
# Out:
# tensor([ 0.7616, -0.9640,  0.9951, -0.9993,  0.9999, -1.0000])

# %%
# apply the tanh activation function to the tensor
y = torch.tanh(x)

# plot the results with a custom color
plt.plot(x.numpy(), y.numpy(), color='blue')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Tanh Activation Function')
plt.show()

# %% [markdown]
# # ReLU Activation Function

# %%
# defining relu
r = nn.ReLU()

# Passing the array to relu function
output = r(input)

print(output)
# Out:
# tensor([1., 0., 3., 0., 5., 0.])

# %%
# apply the ReLU activation function to the tensor
y = torch.relu(x)

# plot the results with a custom color
plt.plot(x.numpy(), y.numpy(), color='green')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('ReLU Activation Function')
plt.show()

# %% [markdown]
# # Softmax Activation Function

# %%
# Calling the Softmax function with
# dimension = 0 as dimension starts
# from 0
soft = nn.Softmax(dim=0)

# Applying function to the tensor
output = soft(input)
print(output)
# Out:
# tensor([1.5862e-02, 7.8971e-04, 1.1720e-01, 1.0688e-04, 8.6602e-01, 1.4464e-05])

# %%
# apply the softmax activation function to the tensor
y = soft(x)

# plot the results with a custom color
plt.plot(x.numpy(), y.numpy(), color='yellow')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Softmax Activation Function')
plt.show()
